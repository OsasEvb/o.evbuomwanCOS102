# %%
import pandas as pd
data = {
    "Name": ["John", "Mary"]
    "Age": [20,22]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Cell In[3], line 3
#     "Name": ["John", "Mary"]
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Names
A = ['Ciara', 'Kevin', 'Liam', 'Baby', 'Whalium', 'Venus', 'Star', 'Lake',]
B = ['biaa', 'Alvin', 'Manly', 'stary', 'lidfm', 'ofoes', 'craa', 'osjf',]
print("Classroom A", A)
print("Classroom B", B)
# Out:
# Classroom A ['Ciara', 'Kevin', 'Liam', 'Baby', 'Whalium', 'Venus', 'Star', 'Lake']
# Classroom B ['biaa', 'Alvin', 'Manly', 'stary', 'lidfm', 'ofoes', 'craa', 'osjf']
