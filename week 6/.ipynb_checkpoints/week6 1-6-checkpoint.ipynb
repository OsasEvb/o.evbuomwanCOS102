# %%
class Parrot:
    pass

# Creating object
obj = Parrot()
print(obj)
# Out:
# <__main__.Parrot object at 0x000001CD89722BA0>

# %%
class Dog:
    attr1 = "mammal"
    attr2 = "dog"

    def fun(self):
        print("I'm a", self.attr1)
        print("I'm a", self.attr2)

# Create object
Rodger = Dog()

# Access attributes
print(Rodger.attr1)

# Call method
Rodger.fun()
# Out:
# mammal
# I'm a mammal
# I'm a dog

# %%
class Car:
    def __init__(self, model, color):
        self.model = model
        self.color = color

    def show(self):
        print("Car model:", self.model)
        print("Car color:", self.color)

# Create object
car1 = Car("Toyota Corolla", "Blue")

# Call method
car1.show()
# Out:
# Car model: Toyota Corolla
# Car color: Blue

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)

# Create objects
s1 = Student("John", 16)
s2 = Student("Mary", 15)

s1.display()
s2.display()
# Out:
# Name: John
# Age: 16
# Name: Mary
# Age: 15

# %%
class Calculator:
    def add(self, a, b):
        return a + b

calc = Calculator()
result = calc.add(5, 3)

print("Sum:", result)
# Out:
# Sum: 8

# %%
class Phone:
    def __init__(self, brand, price):
        self.brand = brand
        self.price = price

    def details(self):
        print("Brand:", self.brand)
        print("Price:", self.price)

p1 = Phone("Samsung", 200000)
p1.details()
# Out:
# Brand: Samsung
# Price: 200000
