# %%
#making data frame from csv file


data = pd.read_csv(C:/Users/Osaso/Downloads/iris (1).csv)

# print data fram
data
# Out:
#   Cell In[7], line 4
#     data = pd.read_csv(C:/Users/Osaso/Downloads/iris (1).csv)
#                         ^
# SyntaxError: invalid syntax
